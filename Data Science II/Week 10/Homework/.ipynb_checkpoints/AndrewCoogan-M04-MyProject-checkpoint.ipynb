# %% [markdown]
# # Milestone 4 - Independent Project
#
# ## Author - Andrew Coogan

# %% [markdown]
# ## Instructions
#
# 1. Generate a clear statement problem and provide location for dataset
# 2. Provide a clear solution to the problem for a non-technical audience
# 3. Visually explore the data to generate insight and include summary statistics
# 4. Use an appropriate statistical analysis method
# 5. Prepare the data via cleaning, normalization, encoding, et cetera
# 6. Generate and evaluate a working model (hypothesis, linear, or time series)
# 7. Draw direct inferences and conclusions from model results
# 8. Use professional coding standards and techniques including:
#
#     - explanatory markdown text
#     - proper code comments
#     - functions to minimize redundant code
#     - minimize hard-coded variables

# %% [markdown]
# ### Note
# Please use the <a class="icon-pdf" title="Independent Project Rubric" href="https://library.startlearninglabs.uw.edu/DATASCI410/Handouts/DATASCI%20410%20Independent%20Project%20Rubric.pdf" target="_blank" rel="noopener">Rubric</a> as a general guide for your project.

# %% [markdown]
# # Abstract
# Magic: The Gathering is a card game that is a combination of resource management and creativity where there are numerous win conditions.  With every new set that is released, new cards are added to the universe and new win conditions are discovered.  In competitive settings there are even banned lists which add special dynamics to the game play.  What I want to focus on are certain keywords used in the cards (deathtouch, lifelink, etc.) and combinations of those and see if the cost of those cards can be projected using other variables.
#
# ## Problem
# As beiefly stated above, there are keywords used on certain kinds of cards (I will elaborate on these as we move on and give very basic introduction for some understanding) and I want to see if there are correlations and dependencies on these keywords.
#
# ## Conclusion
# The magnitude of power * toughness is the best metric for determining converted mana cost.  There are some correlations otherwise but a lot of the factors did not contribute constructively to the models.  The nature of magic the gathering is that each of the colours and types are balanced, so they should share a similar mana curve.  Perhaps for future research, more subsections of the data should be looked into and see if correlation within types and other classifiers can be more telling.  There are also proven neural networks for the creation of new cards.  That approach could be utilized for extracting more hidden layers.

# %%
# Location of dataset

## I have loaded this to my github to avoid unzipping the file from the source location:
## https://mtgjson.com/
data_location = 'https://raw.githubusercontent.com/AndrewCoogan/MagicTutor/master/AllCards.json'

# %%
# Load necessary libraries
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
import seaborn as sns
from sklearn.decomposition import PCA
# %matplotlib inline
# Out:
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
cards = pd.read_json(data_location, orient = "index")
cards.head()
# Out:
#                             cmc    colorIdentity  \
# "Ach! Hans, Run!"           6.0           [R, G]
# "Rumors of My Death . . ."  3.0              [B]
# 1996 World Champion         5.0  [W, U, B, R, G]
# A Display of My Dark Power  0.0              NaN
# A Reckoning Approaches      0.0              NaN
#
#                                                       colors  hand  \
# "Ach! Hans, Run!"                               [Red, Green]   NaN
# "Rumors of My Death . . ."                           [Black]   NaN
# 1996 World Champion         [White, Blue, Black, Red, Green]   NaN
# A Display of My Dark Power                               NaN   NaN
# A Reckoning Approaches                                   NaN   NaN
#
#                                              imageName  layout  life  loyalty  \
# "Ach! Hans, Run!"                    "ach! hans, run!"  normal   NaN      NaN
# "Rumors of My Death . . ."  "rumors of my death . . ."  normal   NaN      NaN
# ...

# %% [markdown]
# There have been sets released such as unhinged or unglued which have 'silly' cards.  These cards do not see normal play as they have odd properties such as infinite mana (read, it costs infinity to cost it), or fractional power and toughness (read, how much damage it can deal/how much damage it can take before being destroyed).  Here I will filter out these "outliers".

# %%
cards_f = cards
cards_f = cards_f.drop(cards[cards.cmc > 30].index)
cards_f = cards_f.drop(cards[cards.layout.str.contains('token', re.IGNORECASE)].index)
cards_f = cards_f.drop(cards[cards.layout.str.contains('scheme', re.IGNORECASE)].index)
cards_f = cards_f.drop(cards[cards.layout.str.contains('plane', re.IGNORECASE)].index)
cards_f = cards_f.drop(cards[cards.layout.str.contains('vanguard', re.IGNORECASE)].index)
cards_f = cards_f.drop(cards[cards.layout.str.contains('phenomenon', re.IGNORECASE)].index)
#cards_f = cards_f.drop(cards.loc[cards.types.str.join('|').str.contains('conspiracy', re.IGNORECASE, na = False).index].index)
#cards_f = cards_f.drop(cards.loc[cards.types.str.join('|').str.contains('host', re.IGNORECASE, na = False).index].index)
cards_f = cards_f.loc[~(cards.cmc == 0.5)]
cards_f = cards_f.loc[~(cards.power == '*²')]
cards_f = cards_f.loc[~(cards.power == '½')]
cards_f = cards_f.loc[~(cards.power == '1½')]
cards_f = cards_f.loc[~(cards.toughness == '1½')]
cards_f = cards_f.loc[~(cards.power == '2½')]
cards_f = cards_f.loc[~(cards.power == '3½')]
cards_f = cards_f.loc[~(cards.toughness == '3½')]
cards_f = cards_f.loc[~(cards.power == '99')]
cards_f = cards_f.loc[~(cards.power == '+1')]
cards_f = cards_f.loc[~(cards.power == '+2')]
cards_f = cards_f.loc[~(cards.power == '+3')]
cards_f = cards_f.loc[~(cards.power == '+4')]
cards_f = cards_f.loc[~(cards.power == '∞')]
cards_f = cards_f.loc[~(cards.power == '?')]

# %% [markdown]
# There are some extra columns we dont really care about, so I am only going to keep a subset of the columns.

# %%
cols_to_keep = ['cmc', 'colorIdentity', 'loyalty', 'manaCost', 'power','toughness','text',
                'subtypes', 'supertypes', 'types']
cards_f = cards_f[cols_to_keep]

# %%
cards_f.head()
# Out:
#                             cmc    colorIdentity  loyalty         manaCost  \
# "Ach! Hans, Run!"           6.0           [R, G]      NaN  {2}{R}{R}{G}{G}
# "Rumors of My Death . . ."  3.0              [B]      NaN           {2}{B}
# 1996 World Champion         5.0  [W, U, B, R, G]      NaN  {W}{U}{B}{R}{G}
# AWOL                        3.0              [W]      NaN           {2}{W}
# Abandon Hope                2.0              [B]      NaN        {X}{1}{B}
#
#                            power toughness  \
# "Ach! Hans, Run!"            NaN       NaN
# "Rumors of My Death . . ."   NaN       NaN
# 1996 World Champion            *         *
# AWOL                         NaN       NaN
# Abandon Hope                 NaN       NaN
#
#                                                                          text  \
# "Ach! Hans, Run!"           At the beginning of your upkeep, you may say "...
# "Rumors of My Death . . ."  {3}{B}, Exile a permanent you control with a L...
# ...

# %%
cards_f.shape
# Out:
# (17879, 10)

# %%
colors = cards_f.colorIdentity.str.join('|').str.get_dummies()
types = cards_f.types.str.join('|').str.get_dummies()
#sub_types = cards_f.subtypes.str.join('|').str.get_dummies()
#super_types = cards_f.supertypes.str.join('|').str.get_dummies()

# %%
picked_text_keywords = ['deathtouch', 'lifelink', 'dredge', 'storm', 'annihilator', 'hexproof', 'shroud', 'flying',
                       'proliferate', 'vigilance', 'defender', 'haste', 'reach', 'flash', 'indestructible', 'delve',
                       'affinity']
picked_text_keywords = [str.upper(t) for t in picked_text_keywords]

keywords = pd.DataFrame(index = cards_f.index)

for k in picked_text_keywords:
    temp_series = pd.Series(index=cards_f.index)
    temp_series[:] = 0
    temp_series.loc[cards_f.loc[cards_f.text.str.contains(k, case = False, na = False)].index] = 1
    keywords[k] = temp_series

# %%
frames = [colors, types, cards_f.cmc, cards_f.loyalty, cards_f.power, cards_f.toughness, keywords]
frames = [pd.DataFrame(item) for item in frames]
cards_d = pd.concat(frames, axis = 1)

# %% [markdown]
# There are a few more names we need to remove...

# %%
cards_d.columns
# Out:
# Index(['B', 'G', 'R', 'U', 'W', 'Artifact', 'Conspiracy', 'Creature',
#        'Eaturecray', 'Enchantment', 'Host', 'Instant', 'Land', 'Planeswalker',
#        'Sorcery', 'Tribal', 'cmc', 'loyalty', 'power', 'toughness',
#        'DEATHTOUCH', 'LIFELINK', 'DREDGE', 'STORM', 'ANNIHILATOR', 'HEXPROOF',
#        'SHROUD', 'FLYING', 'PROLIFERATE', 'VIGILANCE', 'DEFENDER', 'HASTE',
#        'REACH', 'FLASH', 'INDESTRUCTIBLE', 'DELVE', 'AFFINITY'],
#       dtype='object')

# %%
# need to pitch: 'Eaturecray', 'Host', 'Conspiracy', 'Land'

cards_d = cards_d.loc[~(cards_d.Eaturecray == 1)]
cards_d = cards_d.drop('Eaturecray', axis=1)

cards_d = cards_d.loc[~(cards_d.Host == 1)]
cards_d = cards_d.drop('Host', axis=1)

cards_d = cards_d.loc[~(cards_d.Conspiracy == 1)]
cards_d = cards_d.drop('Conspiracy', axis=1)

cards_d = cards_d.loc[~(cards_d.Land == 1)]
cards_d = cards_d.drop('Land', axis=1)

# %%
cards_d.head()
# Out:
#                             B  G  R  U  W  Artifact  Creature  Enchantment  \
# "Ach! Hans, Run!"           0  1  1  0  0         0         0            1
# "Rumors of My Death . . ."  1  0  0  0  0         0         0            1
# 1996 World Champion         1  1  1  1  1         0         1            0
# AWOL                        0  0  0  0  1         0         0            0
# Abandon Hope                1  0  0  0  0         0         0            0
#
#                             Instant  Planeswalker    ...     FLYING  \
# "Ach! Hans, Run!"                 0             0    ...        0.0
# "Rumors of My Death . . ."        0             0    ...        0.0
# 1996 World Champion               0             0    ...        0.0
# AWOL                              1             0    ...        0.0
# Abandon Hope                      0             0    ...        0.0
#
#                             PROLIFERATE  VIGILANCE  DEFENDER HASTE REACH  \
# ...

# %%
types_trimmed = types.columns.tolist()
types_trimmed.remove('Eaturecray')
types_trimmed.remove('Host')
types_trimmed.remove('Conspiracy')
types_trimmed.remove('Land')

intended_order = ['cmc'] + ['power', 'toughness', 'loyalty'] + colors.columns.tolist() + types_trimmed + picked_text_keywords

cards_d = cards_d[intended_order]
cards_d.head()
# Out:
#                             cmc power toughness  loyalty  B  G  R  U  W  \
# "Ach! Hans, Run!"           6.0   NaN       NaN      NaN  0  1  1  0  0
# "Rumors of My Death . . ."  3.0   NaN       NaN      NaN  1  0  0  0  0
# 1996 World Champion         5.0     *         *      NaN  1  1  1  1  1
# AWOL                        3.0   NaN       NaN      NaN  0  0  0  0  1
# Abandon Hope                2.0   NaN       NaN      NaN  1  0  0  0  0
#
#                             Artifact    ...     FLYING  PROLIFERATE  \
# "Ach! Hans, Run!"                  0    ...        0.0          0.0
# "Rumors of My Death . . ."         0    ...        0.0          0.0
# 1996 World Champion                0    ...        0.0          0.0
# AWOL                               0    ...        0.0          0.0
# Abandon Hope                       0    ...        0.0          0.0
#
#                             VIGILANCE  DEFENDER  HASTE  REACH  FLASH  \
# ...

# %%
cards_d[picked_text_keywords].apply(sum, axis = 0)
# Out:
# DEATHTOUCH         158.0
# LIFELINK           185.0
# DREDGE              13.0
# STORM               82.0
# ANNIHILATOR         10.0
# HEXPROOF           109.0
# SHROUD             117.0
# FLYING            2341.0
# PROLIFERATE         16.0
# VIGILANCE          317.0
# DEFENDER           247.0
# HASTE              640.0
# REACH              237.0
# FLASH              348.0
# INDESTRUCTIBLE     144.0
# DELVE               25.0
# AFFINITY            20.0
# dtype: float64

# %%
cards_d[types_trimmed].apply(sum, axis = 0)
# Out:
# Artifact        1878
# Creature        9419
# Enchantment     2259
# Instant         2234
# Planeswalker     107
# Sorcery         1984
# Tribal            54
# dtype: int64

# %% [markdown]
# Planeswalkers posess really complicated mechanics for this analysis.  The way they operate in the game is like a different player and they have abilities that depend on how many times you have activated them in the past.  I am going to remove them from the analysis for now.  I am also going to remove the loyalty column which should only pertain to planeswalkers.

# %%
cards_d = cards_d.loc[~(cards_d.Planeswalker == 1)]
cards_d = cards_d.drop('Planeswalker', axis=1)

cards_d = cards_d.loc[~(cards_d.loyalty == 1)]
cards_d = cards_d.drop('loyalty', axis=1)

types_trimmed.remove('Planeswalker')

# %% [markdown]
# ##  Data Cleaning Done!
#
# Lets take a quick look and see if we can get a basic linear regression to predict cmc using all classifiers.  But first lets see what the density of our target, cmc (converted mana cost), looks like.

# %%
plt.yscale('log', nonposy='clip')
plt.xlabel('Converted Mana Cost (cmc)')
plt.ylabel('Log Count')
plt.title('Histogram of CMC')
plt.hist(cards_d.cmc, bins = len(set(cards_d.cmc)))
# Out:
# (array([1.190e+02, 1.998e+03, 3.592e+03, 4.127e+03, 3.316e+03, 2.069e+03,
#         1.116e+03, 4.770e+02, 1.740e+02, 6.000e+01, 3.000e+01, 1.100e+01,
#         5.000e+00, 1.000e+00, 1.000e+00, 3.000e+00, 1.000e+00]),
#  array([ 0.        ,  0.94117647,  1.88235294,  2.82352941,  3.76470588,
#          4.70588235,  5.64705882,  6.58823529,  7.52941176,  8.47058824,
#          9.41176471, 10.35294118, 11.29411765, 12.23529412, 13.17647059,
#         14.11764706, 15.05882353, 16.        ]),
#  <a list of 17 Patch objects>)

# %% [markdown]
# There are a lot of cards to take into account, and only a very few at the top end of the spectrum (12+ cmc), so I did a log on the y-axis.  Between 2 and 12 there is actually a very nice downward logarithmic curve.

# %%
classifiers = cards_d.columns.tolist()
target_label = 'cmc'
classifiers.remove(target_label)

formula_terms = ' + '.join(classifiers)
formula = target_label + ' ~ ' + formula_terms

ols_model = sm.ols(formula = formula, data = cards_d)

results = ols_model.fit()
n_points = cards_d.shape[0]
y_output = cards_d[target_label].reshape(n_points, 1)

# Get slope (m) and y-intercept (b)
print('Intercept, Slopes : \n{}'.format(results.params))

# Get the t-values (hypothesis test statistics) for linear regression coefficient hypothesis tests.
print('Intercept t-value, Slope t-values: \n{}'.format(results.tvalues))

# Get p-values for above t-value statistics
print('\nHypothesis test summary for each coefficient if they differ from zero:')
print(results.pvalues)

print('\nSSE, SST, SSR, and RMSE:')
mean_y = np.mean(y_output)
sst = np.sum((y_output - mean_y)**2)
sse = sst - results.ssr
print('SSE: {}'.format(sse))
print('SST: {}'.format(sst))
print('SSR: {}'.format(results.ssr))
print('MSE: {}'.format(results.mse_model))
print('RMSE: {}'.format(np.sqrt(results.mse_model)))

# Get most of the linear regression statistics we are interested in:
print(results.summary())

# Plot a histogram of the residuals
sns.distplot(results.resid, hist=True)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Histogram')
# Out:
# Intercept, Slopes :
# Intercept           2.445065e+00
# power[T.+0]        -2.321428e+00
# power[T.-1]         1.664895e-01
# power[T.0]         -1.043323e+00
# power[T.1]         -9.818512e-01
# power[T.1+*]        5.376566e-02
# power[T.10]         1.592511e+00
# power[T.11]         4.636533e+00
# power[T.12]         1.505394e+00
# power[T.13]         6.458159e-01
# power[T.15]         3.600281e+00
# power[T.2]         -3.759789e-01
# power[T.2+*]       -2.237332e-01
# power[T.3]          2.902000e-01
# power[T.4]          6.593770e-01
# power[T.5]          9.606514e-01
# power[T.6]          1.321018e+00
# power[T.7]          1.503939e+00
# power[T.8]          2.096644e+00
# power[T.9]          2.093692e+00
# toughness[T.+4]    -2.321428e+00
# toughness[T.-0]    -4.537222e+00
# toughness[T.-1]     1.906549e-01
# toughness[T.0]      2.987665e-01
# toughness[T.1]     -1.588074e+00
# toughness[T.1+*]   -9.301347e-01
# toughness[T.10]     2.240998e+00
# ...

# %% [markdown]
# Not a bad place to start with an Adj R-Squared of 0.622!  This uses all vaiables that have been slighly trimmed.  Lets see if using just the types (Artifact, Creature, Enchantment, etc), can make anything happen.  I am going to hypothezise no, becuase there is a wide cmc band for each of the types.

# %%
formula_terms = ' + '.join(types_trimmed)
formula = target_label + ' ~ ' + formula_terms

ols_model = sm.ols(formula = formula, data = cards_d)

results = ols_model.fit()
n_points = cards_d.shape[0]
y_output = cards_d[target_label].reshape(n_points, 1)

# Get slope (m) and y-intercept (b)
print('Intercept, Slopes : \n{}'.format(results.params))

# Get the t-values (hypothesis test statistics) for linear regression coefficient hypothesis tests.
print('Intercept t-value, Slope t-values: \n{}'.format(results.tvalues))

# Get p-values for above t-value statistics
print('\nHypothesis test summary for each coefficient if they differ from zero:')
print(results.pvalues)

print('\nSSE, SST, SSR, and RMSE:')
mean_y = np.mean(y_output)
sst = np.sum((y_output - mean_y)**2)
sse = sst - results.ssr
print('SSE: {}'.format(sse))
print('SST: {}'.format(sst))
print('SSR: {}'.format(results.ssr))
print('MSE: {}'.format(results.mse_model))
print('RMSE: {}'.format(np.sqrt(results.mse_model)))

# Get most of the linear regression statistics we are interested in:
print(results.summary())

# Plot a histogram of the residuals
sns.distplot(results.resid, hist=True)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Histogram')
# Out:
# Intercept, Slopes :
# Intercept      2.590892
# Artifact       0.222851
# Creature       1.067962
# Enchantment    0.381440
# Instant        0.026285
# Sorcery        1.005186
# Tribal         0.211299
# dtype: float64
# Intercept t-value, Slope t-values:
# Intercept      33.706573
# Artifact        3.366177
# Creature       14.268173
# Enchantment     4.664248
# Instant         0.311424
# Sorcery        11.783649
# Tribal          0.938793
# dtype: float64
#
# Hypothesis test summary for each coefficient if they differ from zero:
# Intercept      3.408784e-241
# Artifact        7.638557e-04
# Creature        6.341843e-46
# Enchantment     3.120924e-06
# Instant         7.554820e-01
# Sorcery         6.299458e-32
# Tribal          3.478505e-01
# dtype: float64
#
# SSE, SST, SSR, and RMSE:
# SSE: 3023.843212166059
# SST: 49432.68631578947
# SSR: 46408.84310362341
# MSE: 503.97386869434314
# RMSE: 22.449362322666165
#                             OLS Regression Results
# ...

# %% [markdown]
# As mentioned above, this kind of makes sense though as each of these classifiers has a wide range of cmc so none of them are going to have a specific signifier as to how much something should cost.  Lets look at keywords.  I would think that the more keywords there are the more expensive it is.  There are also keywords that are only associated with expensive (such as ANNIHILATOR).  Lets give this one more shot before we try a different approach.

# %%
formula_terms = ' + '.join(picked_text_keywords)
formula = target_label + ' ~ ' + formula_terms

ols_model = sm.ols(formula = formula, data = cards_d)

results = ols_model.fit()
n_points = cards_d.shape[0]
y_output = cards_d[target_label].reshape(n_points, 1)

# Get slope (m) and y-intercept (b)
print('Intercept, Slopes : \n{}'.format(results.params))

# Get the t-values (hypothesis test statistics) for linear regression coefficient hypothesis tests.
print('Intercept t-value, Slope t-values: \n{}'.format(results.tvalues))

# Get p-values for above t-value statistics
print('\nHypothesis test summary for each coefficient if they differ from zero:')
print(results.pvalues)

print('\nSSE, SST, SSR, and RMSE:')
mean_y = np.mean(y_output)
sst = np.sum((y_output - mean_y)**2)
sse = sst - results.ssr
print('SSE: {}'.format(sse))
print('SST: {}'.format(sst))
print('SSR: {}'.format(results.ssr))
print('MSE: {}'.format(results.mse_model))
print('RMSE: {}'.format(np.sqrt(results.mse_model)))

# Get most of the linear regression statistics we are interested in:
print(results.summary())

# Plot a histogram of the residuals
sns.distplot(results.resid, hist=True)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Histogram')
# Out:
# Intercept, Slopes :
# Intercept         3.243351
# DEATHTOUCH       -0.178410
# LIFELINK         -0.034388
# DREDGE           -0.067551
# STORM             0.039157
# ANNIHILATOR       6.921270
# HEXPROOF          0.315182
# SHROUD            0.027095
# FLYING            0.714599
# PROLIFERATE       0.412247
# VIGILANCE         0.579435
# DEFENDER         -0.400110
# HASTE             0.416679
# REACH            -0.127949
# FLASH            -0.116639
# INDESTRUCTIBLE    0.639194
# DELVE             2.785060
# AFFINITY          3.454128
# dtype: float64
# Intercept t-value, Slope t-values:
# Intercept         225.997240
# DEATHTOUCH         -1.323406
# LIFELINK           -0.275123
# DREDGE             -0.146594
# STORM               0.212823
# ANNIHILATOR        13.170560
# HEXPROOF            1.958313
# SHROUD              0.175813
# FLYING             18.828871
# PROLIFERATE         0.992111
# VIGILANCE           6.086722
# DEFENDER           -3.748657
# ...

# %% [markdown]
# I am actually a little surprised by this!  I think this is because certain keywords can be seen in wide ranges of cmc, so it is going to wash out any conbination of signals that may be there.  I think that power and toughness should be an easy case.  I hypothsize that creatures that have higher power and toughness are going to cost more, I am going to multiply power and toughness as well to create a magnitude of the both.
#
# I am also going to filter this set down to just creatures to see how this looks.  In Magic, power and toughness really only apply to creatures.  There are some effects that may change that, but this analysis wouldnt pick up on that.

# %%
formula_terms = ' power + toughness + power:toughness'
formula = target_label + ' ~ ' + formula_terms

ols_model = sm.ols(formula = formula, data = cards_d.loc[cards_d.Creature == 1])

results = ols_model.fit()
n_points = cards_d.shape[0]
y_output = cards_d[target_label].reshape(n_points, 1)

# Get slope (m) and y-intercept (b)
print('Intercept, Slopes : \n{}'.format(results.params))

# Get the t-values (hypothesis test statistics) for linear regression coefficient hypothesis tests.
print('Intercept t-value, Slope t-values: \n{}'.format(results.tvalues))

# Get p-values for above t-value statistics
print('\nHypothesis test summary for each coefficient if they differ from zero:')
print(results.pvalues)

print('\nSSE, SST, SSR, and RMSE:')
mean_y = np.mean(y_output)
sst = np.sum((y_output - mean_y)**2)
sse = sst - results.ssr
print('SSE: {}'.format(sse))
print('SST: {}'.format(sst))
print('SSR: {}'.format(results.ssr))
print('MSE: {}'.format(results.mse_model))
print('RMSE: {}'.format(np.sqrt(results.mse_model)))

# Get most of the linear regression statistics we are interested in:
print(results.summary())

# Plot a histogram of the residuals
sns.distplot(results.resid, hist=True)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Histogram')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# Intercept, Slopes :
# Intercept                      4.588785
# power[T.+0]                   -1.529595
# ...

# %% [markdown]
# This isnt too bad either, but not as good as the orginal run with all of the components!  Its also interesting that this is not a significant improvement over the unfiltered data frame.  I am going to look at PCA quickly.  For this I am going to scale the cmc, and only look at cards with numeric power and toughness (ie, removing the 1+ / * / etc).  Once we get rid of that, we can scale the power and toughnesses.

# %%
cards_s = cards_d.copy()
cards_s['cmc'] = (cards_s['cmc'] - np.nanmean(cards_s.cmc, )) / np.nanstd(cards_s.cmc)
cards_s = cards_s[pd.to_numeric(cards_s.power, errors='coerce').notnull()]
cards_s = cards_s[pd.to_numeric(cards_s.toughness, errors='coerce').notnull()]
cards_s['power'] = pd.to_numeric(cards_s.power, errors='coerce')
cards_s['toughness'] = pd.to_numeric(cards_s.toughness, errors='coerce')
cards_s['power'] = (cards_s['power'] - np.nanmean(cards_s.power, )) / np.nanstd(cards_s.power)
cards_s['toughness'] = (cards_s['toughness'] - np.nanmean(cards_s.toughness, )) / np.nanstd(cards_s.toughness)
cards_s = cards_s.fillna(0)

# %%
classifiers = cards_s.columns.tolist()
target_label = 'cmc'
classifiers.remove(target_label)

pca = PCA(n_components = len(cards_s.columns.tolist()) - 1)
pca_result = pca.fit_transform(cards_s[classifiers])
pca_df = pd.DataFrame(data = pca_result, columns = classifiers)
pca_df[target_label] = cards_s.cmc

# %% [markdown]
# PCA Complete!  Lets see how the residuals look.

# %%
plt.plot(pca_df.iloc[:,2:len(classifiers)])
plt.title('Explained variance by Principal Component Num')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance')
# Out:
# Text(0,0.5,'Explained Variance')

# %%
formula = ' + '.join(classifiers)
pcr_model = sm.ols(formula = 'cmc ~ ' + formula, data = cards_s)

results = pcr_model.fit()

# Get most of the linear regression statistics we are interested in:
print(results.summary())

# Plot a histogram of the residuals
sns.distplot(results.resid, hist=True)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Histogram')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cmc   R-squared:                       0.571
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     456.8
# Date:                Wed, 22 Aug 2018   Prob (F-statistic):               0.00
# Time:                        21:42:31   Log-Likelihood:                -9340.2
# No. Observations:                9304   AIC:                         1.874e+04
# Df Residuals:                    9276   BIC:                         1.894e+04
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -1.1453      0.139     -8.256      0.000      -1.417      -0.873
# ...

# %% [markdown]
# Oof--that is not looking really busy!  There are a lot of classifiers, so maybe if we trim it down we can get some success.  There are such outliers in the above residual distribution too which is very interesting.  Three abilities are sticking out to me: ANNIHILATOR, DELVE, and AFFINITY.  The confidence intervals are positive for all three of these which means that they tend to be on more expensive creatures.

# %%
classifiers = types_trimmed
target_label = 'cmc'

pca = PCA(n_components = len(types_trimmed))
pca_result = pca.fit_transform(cards_s[classifiers])
pca_df = pd.DataFrame(data = pca_result, columns = classifiers)
pca_df[target_label] = cards_s.cmc

# %%
plt.plot(pca_df.iloc[:,2:len(types_trimmed)])
plt.title('Explained variance by Principal Component Num')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance')
# Out:
# Text(0,0.5,'Explained Variance')

# %% [markdown]
# Lets elaborate on this a bit.

# %%
formula = ' + '.join(types_trimmed)
pcr_model = sm.ols(formula = 'cmc ~ ' + formula, data = cards_s)

results = pcr_model.fit()

# Get most of the linear regression statistics we are interested in:
print(results.summary())

# Plot a histogram of the residuals
sns.distplot(results.resid, hist=True)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Histogram')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cmc   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     5.730
# Date:                Wed, 22 Aug 2018   Prob (F-statistic):           0.000650
# Time:                        21:27:23   Log-Likelihood:                -13266.
# No. Observations:                9304   AIC:                         2.654e+04
# Df Residuals:                    9300   BIC:                         2.657e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.1241      0.210     -0.591      0.555      -0.536       0.288
# ...

# %%
pcr_model = sm.ols(formula = 'cmc ~ power + toughness + power:toughness', data = cards_s)

results = pcr_model.fit()

# Get most of the linear regression statistics we are interested in:
print(results.summary())

# Plot a histogram of the residuals
sns.distplot(results.resid, hist=True)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Histogram')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cmc   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     3798.
# Date:                Wed, 22 Aug 2018   Prob (F-statistic):               0.00
# Time:                        21:33:07   Log-Likelihood:                -9553.8
# No. Observations:                9304   AIC:                         1.912e+04
# Df Residuals:                    9300   BIC:                         1.914e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.1995      0.008     26.394      0.000       0.185       0.214
# ...

# %% [markdown]
# This isnt bad!  It looks like the power * toughness metric is the best representation of how cmc is structured, which makes a lot of sense.  There are creatures that have 1 power and 7 toughness and only cost two or there cmc.
